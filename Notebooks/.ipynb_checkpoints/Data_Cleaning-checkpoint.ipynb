# %% [markdown]
# <p style="font-weight:600; font-size:28px; color:yellow; padding-left:8px;">
#     <b>Data Cleaning</b>
# </p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# <p style="font-weight:600; font-size:25px; color:lightgreen; padding-left:8px;">
#     <b>Data Ingestion</b>
# </p>

# %% [markdown]
# <p style="font-weight:600; font-size:25px; color:lightgreen;
#  <b>Data Ingestion</b>n
# </p>

# %%
df = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
# Data copied for future use and to keep original DataFrame intact
# Deep copy
data = df.copy()
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
data.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %% [markdown]
# <p style="font-weight:600; font-size:25px; color:lightgreen; padding-left:8px;">
#   <b>Data Cleaning (Removing unnecessary columns)</b>
# </p>

# %%
# Person ID column is dropped
data.drop('Person ID', axis=1, inplace=True)
data
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 0                         42             6   Overweight         126/83
# 1                         60             8       Normal         125/80
# 2                         60             8       Normal         125/80
# 3                         30             8        Obese         140/90
# 4                         30             8        Obese         140/90
# ..                       ...           ...          ...            ...
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
# 373                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 0            77         4200            NaN
# 1            75        10000            NaN
# 2            75        10000            NaN
# 3            85         3000    Sleep Apnea
# 4            85         3000    Sleep Apnea
# ..          ...          ...            ...
# 369          68         7000    Sleep Apnea
# 370          68         7000    Sleep Apnea
# 371          68         7000    Sleep Apnea
# 372          68         7000    Sleep Apnea
# 373          68         7000    Sleep Apnea
#
# [374 rows x 12 columns]

# %%
# Occupation is dropped as this column is useless, will just increase Curse of Dimensionality

data.drop('Occupation', axis=1, inplace=True)

data
# Out:
#      Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0      Male   27             6.1                 6                       42
# 1      Male   28             6.2                 6                       60
# 2      Male   28             6.2                 6                       60
# 3      Male   28             5.9                 4                       30
# 4      Male   28             5.9                 4                       30
# ..      ...  ...             ...               ...                      ...
# 369  Female   59             8.1                 9                       75
# 370  Female   59             8.0                 9                       75
# 371  Female   59             8.1                 9                       75
# 372  Female   59             8.1                 9                       75
# 373  Female   59             8.1                 9                       75
#
#      Stress Level BMI Category Blood Pressure  Heart Rate  Daily Steps  \
# 0               6   Overweight         126/83          77         4200
# 1               8       Normal         125/80          75        10000
# 2               8       Normal         125/80          75        10000
# 3               8        Obese         140/90          85         3000
# 4               8        Obese         140/90          85         3000
# ..            ...          ...            ...         ...          ...
# 369             3   Overweight         140/95          68         7000
# 370             3   Overweight         140/95          68         7000
# 371             3   Overweight         140/95          68         7000
# 372             3   Overweight         140/95          68         7000
# 373             3   Overweight         140/95          68         7000
#
#     Sleep Disorder
# 0              NaN
# 1              NaN
# 2              NaN
# 3      Sleep Apnea
# 4      Sleep Apnea
# ..             ...
# 369    Sleep Apnea
# 370    Sleep Apnea
# 371    Sleep Apnea
# 372    Sleep Apnea
# 373    Sleep Apnea
#
# [374 rows x 11 columns]

# %%
# Shifting target -> Quality of Sleep to the last column
data1 = data.drop('Quality of Sleep', axis=1) 
data1['Quality_of_Sleep'] = data['Quality of Sleep']

# %%
data1
# Out:
#      Gender  Age  Sleep Duration  Physical Activity Level  Stress Level  \
# 0      Male   27             6.1                       42             6
# 1      Male   28             6.2                       60             8
# 2      Male   28             6.2                       60             8
# 3      Male   28             5.9                       30             8
# 4      Male   28             5.9                       30             8
# ..      ...  ...             ...                      ...           ...
# 369  Female   59             8.1                       75             3
# 370  Female   59             8.0                       75             3
# 371  Female   59             8.1                       75             3
# 372  Female   59             8.1                       75             3
# 373  Female   59             8.1                       75             3
#
#     BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder  \
# 0     Overweight         126/83          77         4200            NaN
# 1         Normal         125/80          75        10000            NaN
# 2         Normal         125/80          75        10000            NaN
# 3          Obese         140/90          85         3000    Sleep Apnea
# 4          Obese         140/90          85         3000    Sleep Apnea
# ..           ...            ...         ...          ...            ...
# 369   Overweight         140/95          68         7000    Sleep Apnea
# 370   Overweight         140/95          68         7000    Sleep Apnea
# 371   Overweight         140/95          68         7000    Sleep Apnea
# 372   Overweight         140/95          68         7000    Sleep Apnea
# 373   Overweight         140/95          68         7000    Sleep Apnea
#
#      Quality_of_Sleep
# 0                   6
# 1                   6
# 2                   6
# 3                   4
# 4                   4
# ..                ...
# 369                 9
# 370                 9
# 371                 9
# 372                 9
# 373                 9
#
# [374 rows x 11 columns]

# %%
data1.info()
# 4 Categorical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   374 non-null    object
#  1   Age                      374 non-null    int64
#  2   Sleep Duration           374 non-null    float64
#  3   Physical Activity Level  374 non-null    int64
#  4   Stress Level             374 non-null    int64
#  5   BMI Category             374 non-null    object
#  6   Blood Pressure           374 non-null    object
#  7   Heart Rate               374 non-null    int64
#  8   Daily Steps              374 non-null    int64
#  9   Sleep Disorder           155 non-null    object
#  10  Quality_of_Sleep         374 non-null    int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 32.3+ KB

# %%
data1.isna().sum()
# There is only NaN values in Sleep Disorder, but that means its valid, so no need to remove NaN values here
# Out:
# Gender                       0
# Age                          0
# Sleep Duration               0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# Quality_of_Sleep             0
# dtype: int64

# %%
# Replacing NaN in Sleep Disorder column with "Normal", for ease of data cleaning.
data1['Sleep Disorder'].fillna('Normal', inplace=True)

# %%
# Checking Numerical columns
data1.select_dtypes(include='number').describe()
# Out:
#               Age  Sleep Duration  Physical Activity Level  Stress Level  \
# count  374.000000      374.000000               374.000000    374.000000
# mean    42.184492        7.132086                59.171123      5.385027
# std      8.673133        0.795657                20.830804      1.774526
# min     27.000000        5.800000                30.000000      3.000000
# 25%     35.250000        6.400000                45.000000      4.000000
# 50%     43.000000        7.200000                60.000000      5.000000
# 75%     50.000000        7.800000                75.000000      7.000000
# max     59.000000        8.500000                90.000000      8.000000
#
#        Heart Rate   Daily Steps  Quality_of_Sleep
# count  374.000000    374.000000        374.000000
# mean    70.165775   6816.844920          7.312834
# std      4.135676   1617.915679          1.196956
# min     65.000000   3000.000000          4.000000
# 25%     68.000000   5600.000000          6.000000
# 50%     70.000000   7000.000000          7.000000
# 75%     72.000000   8000.000000          8.000000
# max     86.000000  10000.000000          9.000000

# %%
data1.select_dtypes(include='object')
# Out:
#      Gender BMI Category Blood Pressure Sleep Disorder
# 0      Male   Overweight         126/83         Normal
# 1      Male       Normal         125/80         Normal
# 2      Male       Normal         125/80         Normal
# 3      Male        Obese         140/90    Sleep Apnea
# 4      Male        Obese         140/90    Sleep Apnea
# ..      ...          ...            ...            ...
# 369  Female   Overweight         140/95    Sleep Apnea
# 370  Female   Overweight         140/95    Sleep Apnea
# 371  Female   Overweight         140/95    Sleep Apnea
# 372  Female   Overweight         140/95    Sleep Apnea
# 373  Female   Overweight         140/95    Sleep Apnea
#
# [374 rows x 4 columns]

# %%
# Listing Numerical and Categorical columns

numerical_cols = data1.select_dtypes(include='number').columns.to_list()
categorical_cols = data1.select_dtypes(include='object').columns.to_list()

print(f"Numerical columns = {numerical_cols}\n")
print(f"Categorical columns = {categorical_cols}")
# Out:
# Numerical columns = ['Age', 'Sleep Duration', 'Physical Activity Level', 'Stress Level', 'Heart Rate', 'Daily Steps', 'Quality_of_Sleep']
#
# Categorical columns = ['Gender', 'BMI Category', 'Blood Pressure', 'Sleep Disorder']

# %%
for col in categorical_cols:
    print(f"{data1[col].value_counts()}\n")
# Out:
# Gender
# Male      189
# Female    185
# Name: count, dtype: int64
#
# BMI Category
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: count, dtype: int64
#
# Blood Pressure
# 130/85    99
# 140/95    65
# 125/80    65
# 120/80    45
# 115/75    32
# 135/90    27
# 140/90     4
# 125/82     4
# 132/87     3
# 128/85     3
# 126/83     2
# 115/78     2
# 139/91     2
# 142/92     2
# 119/77     2
# 135/88     2
# 129/84     2
# 128/84     2
# 131/86     2
# 117/76     2
# 130/86     2
# 118/75     2
# 121/79     1
# 122/80     1
# 118/76     1
# Name: count, dtype: int64
#
# Sleep Disorder
# Normal         219
# Sleep Apnea     78
# Insomnia        77
# Name: count, dtype: int64

# %%
data1.duplicated().sum()
# Here we can see there is no duplicates
# Out:
# 244

# %%
data1
# Out:
#      Gender  Age  Sleep Duration  Physical Activity Level  Stress Level  \
# 0      Male   27             6.1                       42             6
# 1      Male   28             6.2                       60             8
# 2      Male   28             6.2                       60             8
# 3      Male   28             5.9                       30             8
# 4      Male   28             5.9                       30             8
# ..      ...  ...             ...                      ...           ...
# 369  Female   59             8.1                       75             3
# 370  Female   59             8.0                       75             3
# 371  Female   59             8.1                       75             3
# 372  Female   59             8.1                       75             3
# 373  Female   59             8.1                       75             3
#
#     BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder  \
# 0     Overweight         126/83          77         4200         Normal
# 1         Normal         125/80          75        10000         Normal
# 2         Normal         125/80          75        10000         Normal
# 3          Obese         140/90          85         3000    Sleep Apnea
# 4          Obese         140/90          85         3000    Sleep Apnea
# ..           ...            ...         ...          ...            ...
# 369   Overweight         140/95          68         7000    Sleep Apnea
# 370   Overweight         140/95          68         7000    Sleep Apnea
# 371   Overweight         140/95          68         7000    Sleep Apnea
# 372   Overweight         140/95          68         7000    Sleep Apnea
# 373   Overweight         140/95          68         7000    Sleep Apnea
#
#      Quality_of_Sleep
# 0                   6
# 1                   6
# 2                   6
# 3                   4
# 4                   4
# ..                ...
# 369                 9
# 370                 9
# 371                 9
# 372                 9
# 373                 9
#
# [374 rows x 11 columns]

# %%
# Have to change the Blood Pressure column as its in a inconsistent form
data1['Blood Pressure']
# Out:
# 0      126/83
# 1      125/80
# 2      125/80
# 3      140/90
# 4      140/90
#         ...
# 369    140/95
# 370    140/95
# 371    140/95
# 372    140/95
# 373    140/95
# Name: Blood Pressure, Length: 374, dtype: object

# %%
type(data1['Blood Pressure'][0])
# Data is in string format
# Out:
# str

# %%
data1[['Systolic_BP', 'Diastolic_BP']] = data1['Blood Pressure'].str.split('/', expand=True)
# Making two separate columns for Systolic and Diastolic BP
data1[['Systolic_BP', 'Diastolic_BP']]
# Out:
#     Systolic_BP Diastolic_BP
# 0           126           83
# 1           125           80
# 2           125           80
# 3           140           90
# 4           140           90
# ..          ...          ...
# 369         140           95
# 370         140           95
# 371         140           95
# 372         140           95
# 373         140           95
#
# [374 rows x 2 columns]

# %%
# Convert ['Systolic_BP', 'Diastolic_BP'] into numeric

data1['Systolic_BP'] = pd.to_numeric(data1['Systolic_BP'])
data1['Diastolic_BP'] = pd.to_numeric(data1['Systolic_BP'])

print(f"{type(data1['Systolic_BP'][0])}\n{type(data1['Diastolic_BP'][0])}")
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>

# %%
# Now drop Blood Pressure column

data1.drop('Blood Pressure', axis=1, inplace=True) -> done
data1
# Out:
#      Gender  Age  Sleep Duration  Physical Activity Level  Stress Level  \
# 0      Male   27             6.1                       42             6
# 1      Male   28             6.2                       60             8
# 2      Male   28             6.2                       60             8
# 3      Male   28             5.9                       30             8
# 4      Male   28             5.9                       30             8
# ..      ...  ...             ...                      ...           ...
# 369  Female   59             8.1                       75             3
# 370  Female   59             8.0                       75             3
# 371  Female   59             8.1                       75             3
# 372  Female   59             8.1                       75             3
# 373  Female   59             8.1                       75             3
#
#     BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder  \
# 0     Overweight         126/83          77         4200         Normal
# 1         Normal         125/80          75        10000         Normal
# 2         Normal         125/80          75        10000         Normal
# 3          Obese         140/90          85         3000    Sleep Apnea
# 4          Obese         140/90          85         3000    Sleep Apnea
# ..           ...            ...         ...          ...            ...
# 369   Overweight         140/95          68         7000    Sleep Apnea
# 370   Overweight         140/95          68         7000    Sleep Apnea
# 371   Overweight         140/95          68         7000    Sleep Apnea
# 372   Overweight         140/95          68         7000    Sleep Apnea
# 373   Overweight         140/95          68         7000    Sleep Apnea
#
#      Quality_of_Sleep  Systolic_BP  Diastolic_BP
# 0                   6          126           126
# 1                   6          125           125
# 2                   6          125           125
# 3                   4          140           140
# 4                   4          140           140
# ..                ...          ...           ...
# 369                 9          140           140
# 370                 9          140           140
# 371                 9          140           140
# 372                 9          140           140
# 373                 9          140           140
#
# [374 rows x 13 columns]

# %%
data1.columns
# Out:
# Index(['Gender', 'Age', 'Sleep Duration', 'Physical Activity Level',
#        'Stress Level', 'BMI Category', 'Blood Pressure', 'Heart Rate',
#        'Daily Steps', 'Sleep Disorder', 'Quality_of_Sleep', 'Systolic_BP',
#        'Diastolic_BP'],
#       dtype='object')

# %% [markdown]
# <p style="font-weight:600; font-size:25px; color:lightgreen; padding-left:8px;">
#     <b>Outlier Detection</b>
# </p>

# %%
# Loop through each numeric column
for col in numerical_cols:
    Q1 = data1[col].quantile(0.25)
    Q3 = data1[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Count outliers
    outliers = data1[(data1[col] < lower_bound) | (data1[col] > upper_bound)]
    outlier_count = outliers.shape[0]
    
    print(f"{col}: {outlier_count} outliers")
    
    # Plot boxplot
    plt.figure(figsize=(6,4))
    sns.boxplot(x=data1[col])
    plt.title(f"Boxplot of {col} (Outliers: {outlier_count})")
    plt.show()
# Out:
# Age: 0 outliers
# Sleep Duration: 0 outliers
# Physical Activity Level: 0 outliers
# Stress Level: 0 outliers
# Heart Rate: 15 outliers
# Daily Steps: 0 outliers
# Quality_of_Sleep: 0 outliers

# %%
# Check outliers
for col in numerical_cols:
    Q1 = data1[col].quantile(0.25)
    Q3 = data1[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Count outliers
    outliers = data1[col][(data1[col] < lower_bound) | (data1[col] > upper_bound)]
    outlier_count = outliers.shape[0]
    if(outlier_count != 0):
        print(f"{col} \n{outliers}\n")

"""These outliers are important for model training.
    Some people may sleep for almost 12 horus 
    Some people's sleep score may be between 20-30
"""
# Out:
# Heart Rate
# 3      85
# 4      85
# 5      85
# 6      82
# 16     80
# 18     80
# 80     81
# 81     81
# 93     84
# 145    84
# 147    80
# 264    83
# 266    83
# 276    86
# 277    86
# Name: Heart Rate, dtype: int64
# "These outliers are important for model training.\n    Some people may sleep for almost 12 horus \n    Some people's sleep score may be between 20-30\n"

# %%
data1.describe(include='number')
# Out:
#               Age  Sleep Duration  Physical Activity Level  Stress Level  \
# count  374.000000      374.000000               374.000000    374.000000
# mean    42.184492        7.132086                59.171123      5.385027
# std      8.673133        0.795657                20.830804      1.774526
# min     27.000000        5.800000                30.000000      3.000000
# 25%     35.250000        6.400000                45.000000      4.000000
# 50%     43.000000        7.200000                60.000000      5.000000
# 75%     50.000000        7.800000                75.000000      7.000000
# max     59.000000        8.500000                90.000000      8.000000
#
#        Heart Rate   Daily Steps  Quality_of_Sleep  Systolic_BP  Diastolic_BP
# count  374.000000    374.000000        374.000000   374.000000    374.000000
# mean    70.165775   6816.844920          7.312834   128.553476    128.553476
# std      4.135676   1617.915679          1.196956     7.748118      7.748118
# min     65.000000   3000.000000          4.000000   115.000000    115.000000
# 25%     68.000000   5600.000000          6.000000   125.000000    125.000000
# 50%     70.000000   7000.000000          7.000000   130.000000    130.000000
# 75%     72.000000   8000.000000          8.000000   135.000000    135.000000
# max     86.000000  10000.000000          9.000000   142.000000    142.000000

# %%
data2 = data1.drop('Quality_of_Sleep', axis=1)

# %%
data2['Quality_of_Sleep'] = data1['Quality_of_Sleep']

# %%
data2
# Out:
#      Gender  Age  Sleep Duration  Physical Activity Level  Stress Level  \
# 0      Male   27             6.1                       42             6
# 1      Male   28             6.2                       60             8
# 2      Male   28             6.2                       60             8
# 3      Male   28             5.9                       30             8
# 4      Male   28             5.9                       30             8
# ..      ...  ...             ...                      ...           ...
# 369  Female   59             8.1                       75             3
# 370  Female   59             8.0                       75             3
# 371  Female   59             8.1                       75             3
# 372  Female   59             8.1                       75             3
# 373  Female   59             8.1                       75             3
#
#     BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder  \
# 0     Overweight         126/83          77         4200         Normal
# 1         Normal         125/80          75        10000         Normal
# 2         Normal         125/80          75        10000         Normal
# 3          Obese         140/90          85         3000    Sleep Apnea
# 4          Obese         140/90          85         3000    Sleep Apnea
# ..           ...            ...         ...          ...            ...
# 369   Overweight         140/95          68         7000    Sleep Apnea
# 370   Overweight         140/95          68         7000    Sleep Apnea
# 371   Overweight         140/95          68         7000    Sleep Apnea
# 372   Overweight         140/95          68         7000    Sleep Apnea
# 373   Overweight         140/95          68         7000    Sleep Apnea
#
#      Systolic_BP  Diastolic_BP  Quality_of_Sleep
# 0            126           126                 6
# 1            125           125                 6
# 2            125           125                 6
# 3            140           140                 4
# 4            140           140                 4
# ..           ...           ...               ...
# 369          140           140                 9
# 370          140           140                 9
# 371          140           140                 9
# 372          140           140                 9
# 373          140           140                 9
#
# [374 rows x 13 columns]

# %%
# Convert into csv file for further use
data2.to_csv('Cleaned_Dataset.csv', index=False)
print('Successfully saved as Cleaned_Dataset.csv')
# Out:
# Successfully saved as Cleaned_Dataset.csv

# %% [markdown]
# <p style="font-weight:600; font-size:25px; color:yellow; padding-left:8px;">
#     <b>Ending Data Cleaning here.</b>
# </p>
#
# <p style="font-weight:600; font-size:25px; color:purple; padding-left:8px;">
#     All Data Cleaning Steps are done:
# </p>
# <ul style="font-size:20px; color:offwhite; padding-left:30px;">
#     <li>Data Ingestion</li>
#     <li>Removing unnecessary features</li>
#     <li>Checking Outliers</li>
#     <li>Handled Blood Pressure column</li>
# </ul>
